# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
HouseDF = pd.read_csv(r'C:\Users\hp\OneDrive\Documents\GitHub\CodeAlpha_Predictive_Modelling\USA_Housing.csv', index_col = 0)

# %%
HouseDF.head()
# Out:
#                   Avg. Area House Age  Avg. Area Number of Rooms  \
# Avg. Area Income
# 79545.458574                 5.682861                   7.009188
# 79248.642455                 6.002900                   6.730821
# 61287.067179                 5.865890                   8.512727
# 63345.240046                 7.188236                   5.586729
# 59982.197226                 5.040555                   7.839388
#
#                   Avg. Area Number of Bedrooms  Area Population         Price  \
# Avg. Area Income
# 79545.458574                              4.09     23086.800503  1.059034e+06
# 79248.642455                              3.09     40173.072174  1.505891e+06
# 61287.067179                              5.13     36882.159400  1.058988e+06
# 63345.240046                              3.26     34310.242831  1.260617e+06
# 59982.197226                              4.23     26354.109472  6.309435e+05
#
#                                                             Address
# ...

# %%
HouseDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 5000 entries, 79545.45857431678 to 65510.581803666224
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area House Age           5000 non-null   float64
#  1   Avg. Area Number of Rooms     5000 non-null   float64
#  2   Avg. Area Number of Bedrooms  5000 non-null   float64
#  3   Area Population               5000 non-null   float64
#  4   Price                         5000 non-null   float64
#  5   Address                       5000 non-null   object
# dtypes: float64(5), object(1)
# memory usage: 273.4+ KB

# %%
HouseDF.describe()
# Out:
#        Avg. Area House Age  Avg. Area Number of Rooms  \
# count          5000.000000                5000.000000
# mean              5.977222                   6.987792
# std               0.991456                   1.005833
# min               2.644304                   3.236194
# 25%               5.322283                   6.299250
# 50%               5.970429                   7.002902
# 75%               6.650808                   7.665871
# max               9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928702  9.975771e+05
# 50%                        4.050000     36199.406689  1.232669e+06
# ...

# %%
HouseDF.columns
# Out:
# Index(['Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
sns.pairplot(HouseDF)

# %%
sns.heatmap(HouseDF.corr(), annot=True)
# Out:
# <Axes: >

# %%
X = HouseDF[['Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address']]

y = HouseDF['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=101)

# %%
X_train
# Out:
#                   Avg. Area House Age  Avg. Area Number of Rooms  \
# Avg. Area Income
# 68091.179676                 5.364208                   7.502956
# 75729.765546                 5.580599                   7.642973
# 70885.420819                 6.358747                   7.250241
# 73386.407340                 4.966360                   7.915453
# 75046.313791                 5.351169                   7.797825
# ...                               ...                        ...
# 56610.642563                 4.846832                   7.558137
# 70596.850945                 6.548274                   6.539986
# 55621.899104                 3.735942                   6.868291
# 63044.460096                 5.935261                   5.913454
# 75078.791516                 7.644779                   8.440726
#
#                   Avg. Area Number of Bedrooms  Area Population         Price  \
# Avg. Area Income
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
X_train = HouseDF.drop(['Price', 'Address'], axis=1)
y_train = HouseDF['Price']

print(X_train.dtypes)

X_train = pd.get_dummies(X)

model = LinearRegression()

model.fit(X_train, y_train)

print(model.coef_)
# Out:
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# dtype: object
# [ 164969.71779097  114803.95606166    7485.04048743 ...    5226.81693474
#  -151700.95804712 -415574.07704288]

# %%
model.fit(X_train, y_train)
print(model.coef_)
# Out:
# [ 164969.71779097  114803.95606166    7485.04048743 ...    5226.81693474
#  -151700.95804712 -415574.07704288]

# %%
from sklearn.model_selection import train_test_split

coeff_df = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])
print(coeff_df)
# Out:
#                                 Coefficient
# Avg. Area House Age           163682.083078
# Avg. Area Number of Rooms     114024.775675
# Avg. Area Number of Bedrooms    8947.680839
# Area Population                   14.780367

# %%
predictions = model.predict(X_test)
plt.scatter(y_test, predictions)

# %%
sns.distplot((y_test-predictions), bins=50);
